# %% [markdown]
# # Version

# %%
import torch 
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 5070 Ti

# %%
import torch
import torchvision

print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("Is CUDA available?", torch.cuda.is_available())
print("GPU Device:",torch.cuda.get_device_name(0))
print("GPU Memory (bytes):",torch.cuda.get_device_properties(0).total_memory)
print("GPU major version:",torch.cuda.get_device_properties(0).major)
# Out:
# PyTorch version: 2.10.0+cu128
# Torchvision version: 0.25.0+cu128
# Is CUDA available? True
# GPU Device: NVIDIA GeForce RTX 5070 Ti
# GPU Memory (bytes): 17094475776
# GPU major version: 12

# %%
torch.autocast(device_type="cuda", dtype=torch.bfloat16).__enter__()

if torch.cuda.get_device_properties(0).major >= 8:
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.allow_tf32 = True

# %% [markdown]
# # Leer variables de entorno del .env

# %%
import os
from dotenv import load_dotenv

# Load variables from .env into os.environ
load_dotenv()

HF_TOKEN  = os.getenv("HF_TOKEN")
print(HF_TOKEN )
# Out:
# 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

# %% [markdown]
# # Descargar Modelo

# %%
from sam3.model_builder import build_sam3_image_model
from sam3.model.sam3_image_processor import Sam3Processor

model = build_sam3_image_model(bpe_path="sam3/assets/bpe_simple_vocab_16e6.txt.gz")
processor = Sam3Processor(model, confidence_threshold=0.3)

# %%
import supervision as sv

def from_sam(sam_result: dict) -> sv.Detections:
    xyxy = sam_result["boxes"].to(torch.float32).cpu().numpy()
    confidence = sam_result["scores"].to(torch.float32).cpu().numpy()

    mask = sam_result["masks"].to(torch.bool)
    mask = mask.reshape(mask.shape[0], mask.shape[2], mask.shape[3]).cpu().numpy()

    return sv.Detections(
        xyxy=xyxy,
        confidence=confidence,
        mask=mask
    )

# %%
import supervision as sv
from PIL import Image
from typing import Optional

COLOR = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff8080", "#ff66b2", "#ff66ff", "#b266ff",
    "#9999ff", "#3399ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])


def annotate(
    image: Image.Image,
    detections: sv.Detections,
    label: Optional[str] = None
) -> Image.Image:

    text_scale = sv.calculate_optimal_text_scale(
        resolution_wh=image.size
    )

    mask_annotator = sv.MaskAnnotator(
        color=COLOR,
        color_lookup=sv.ColorLookup.CLASS,
        opacity=0.6
    )

    box_annotator = sv.BoxAnnotator(
        color=COLOR,
        color_lookup=sv.ColorLookup.CLASS,
        thickness=1
    )

    label_annotator = sv.LabelAnnotator(
        color=COLOR,
        color_lookup=sv.ColorLookup.CLASS,
        text_scale=0.4,
        text_padding=5,
        text_color=sv.Color.BLACK,
        text_thickness=1
    )

    CLASS_NAMES = {
        0: "ball",
        1: "car",
        2: "soccer field"
    }

    labels = [
        f"{CLASS_NAMES[class_id]} {confidence:.2f}"
        for class_id, confidence in zip(
            detections.class_id,
            detections.confidence
        )
    ]

    annotated_image = image.copy()

    annotated_image = mask_annotator.annotate(
        annotated_image,
        detections
    )

    annotated_image = box_annotator.annotate(
        annotated_image,
        detections
    )

    annotated_image = label_annotator.annotate(
        annotated_image,
        detections,
        labels
    )

    return annotated_image

# %%
from PIL import Image
from IPython.display import display
import numpy as np
import supervision as sv

prompts = ["ball", "car", "soccer field"]

CLASS_IDS = {
    "ball": 0,
    "car": 1,
    "soccer field": 2
}

IMAGE_PATH = "futbot.jpg"

image = Image.open(IMAGE_PATH).convert("RGB")
inference_state = processor.set_image(image)

all_detections = []

for prompt in prompts:

    inference_state = processor.set_text_prompt(
        state=inference_state,
        prompt=prompt
    )

    detections = from_sam(sam_result=inference_state)
    detections = detections[detections.confidence > 0.5]

    # Asignar class_id
    detections.class_id = np.full(
        len(detections),
        CLASS_IDS[prompt],
        dtype=np.int32
    )

    print(f"There are {len(detections)} {prompt} objects detected in the image.")

    all_detections.append(detections)

# Unir todas las detecciones
detections = sv.Detections.merge(all_detections)

# Crear etiquetas
labels = []
for class_id, confidence in zip(
    detections.class_id,
    detections.confidence
):
    class_name = list(CLASS_IDS.keys())[list(CLASS_IDS.values()).index(class_id)]
    labels.append(f"{class_name} {confidence:.2f}")

# Anotar una sola vez
image = annotate(image, detections)

image.save("image_segmentation.jpg")
display(image)
# Out:
# There are 1 ball objects detected in the image.
# There are 6 car objects detected in the image.
# There are 1 soccer field objects detected in the image.
# <PIL.Image.Image image mode=RGB size=1280x720>
